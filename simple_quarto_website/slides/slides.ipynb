# %% [markdown]
# ---
# title: "My Presentation with ipsum lorem"
# author: "Nadav Gerner"
# execute:
#   enabled: true
#   echo: true
#   kernel: python3
#
# format:
#     revealjs:
#         slide-number: true
#         code-fold: true
#
# ---

# %% [markdown]
# ## Quote
#
# > Take the challenges hosted by the machine learning competition site Kaggle for example. Among the 29 challenge winning solutions 3 published at Kaggle’s blog during 2015, 17 solutions used XGBoost. Among these solutions, eight solely used XGBoost to train the model, while most others combined XGBoost with neural nets in ensembles [@chen2016xgboost]
#
# ## Picture 1
#
# ![A distribution of house sales prices before log transform:](images/BeforeLogTransform.png)
#
# ## Picture 2
#
# ![A distribution of house sales prices after log transform:](images/AfterLogTransform.png)
#
# ## Code Block

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some data
x = np.linspace(0, 10, 100)
y = np.cos(x)

# Plotting the data
plt.plot(x, y)
plt.title("Cosine Function")
plt.xlabel("x")
plt.ylabel("cos(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## References
