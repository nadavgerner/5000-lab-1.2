# %% [markdown]
# ---
# title: "About"
# format:
#     html:
#         code-fold: true
# execute:
#   enabled: true
#
# ---

# %% [markdown]
# # Header 1
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
#
#
# ## Header 2
#
# Ridiculus est inceptos enim mattis eros odio etiam suscipit. Justo nascetur condimentum risus et nostra vestibulum convallis blandit. Eros pretium suscipit aenean libero augue scelerisque in. Aenean nam enim consequat nam eu cras suscipit. Commodo ullamcorper euismod efficitur; ultricies quis risus. Justo luctus dolor commodo, class viverra lobortis finibus.
#
# Quis malesuada morbi enim himenaeos; montes tortor interdum. Interdum sapien faucibus vulputate nisl dapibus suspendisse neque. Magna suscipit turpis gravida bibendum curae tincidunt. Et turpis fermentum class sollicitudin potenti magnis sed. Magnis penatibus condimentum ipsum ullamcorper cursus rutrum venenatis facilisis. Augue sollicitudin nam cursus ultricies tempor cursus varius. Primis diam curabitur accumsan aliquet diam cursus. Quis ipsum commodo ultricies a non vulputate consequat potenti.
#
# # Header 3
#
# Lacinia inceptos accumsan cubilia nam cursus viverra. Ac dui ac pulvinar nec velit. Consectetur nisl cras ultrices ornare consectetur aliquam taciti. Euismod torquent nullam neque et interdum condimentum nunc. Elit bibendum vulputate montes turpis turpis sociosqu nam volutpat. Per non praesent diam fames dis morbi venenatis. Rhoncus sagittis dui egestas; purus vivamus scelerisque mi nam.
#
# Morbi netus parturient feugiat elit sed neque lectus. Imperdiet fermentum scelerisque magna cursus habitant adipiscing. Ac cras condimentum luctus sagittis suscipit placerat id aliquet pulvinar. Curabitur suscipit egestas gravida aenean fames scelerisque turpis. Est tortor lacus ridiculus lobortis id ac, interdum laoreet. Nullam nisl magnis torquent metus elementum nullam nulla. Convallis pulvinar integer at aliquet ac consectetur sociosqu duis.
#
# # Python code

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 100, 5) 
y = x * 2

plt.figure(figsize=(8, 6))
plt.plot(x, y)

plt.title('Plot of y = 2x')
plt.xlabel('x')
plt.ylabel('y')

plt.grid(True)
plt.show()
